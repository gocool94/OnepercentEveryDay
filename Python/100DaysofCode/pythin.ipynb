# %% [markdown]
# | Function                                 | Tuple               | List                        | Dictionary                               | Set                                             |
# | ---------------------------------------- | ------------------- | --------------------------- | ---------------------------------------- | ----------------------------------------------- |
# | **Access by Index**                      | Yes                 | Yes                         | N/A                                      | N/A                                             |
# | **Access by Key/Value Pair**             | N/A                 | N/A                         | Yes                                      | N/A                                             |
# | **Add Element**                          | N/A                 | Append (`append()`)         | Add Key-Value Pair (`dict[key] = value`) | Add Element (`add()`)                           |
# | **Remove Element**                       | N/A                 | Remove (`remove()`)         | Remove Key-Value Pair (`del dict[key]`)  | Remove Element (`remove()`)                     |
# | **Discard Element**                      | N/A                 | N/A                         | N/A                                      | Discard Element (`discard()`)                   |
# | **Check Membership**                     | Yes                 | `in` and `not in` operators | `in` and `not in` operators              | `in` and `not in` operators                     |
# | **Length**                               | `len()`             | `len()`                     | `len()`                                  | `len()`                                         |
# | **Concatenation**                        | `+` (concatenation) | `+` (concatenation)         | N/A                                      | Union (`union()`)                               |
# | **Slicing**                              | Yes                 | Yes                         | N/A                                      | N/A                                             |
# | **Iteration**                            | Yes                 | Yes                         | Keys, Values, Items                      | Elements                                        |
# | **Sorting**                              | N/A                 | `sort()`                    | N/A                                      | N/A                                             |
# | **Copying**                              | Yes (shallow copy)  | `copy()` (shallow copy)     | `copy()` (shallow copy)                  | `copy()` (shallow copy)                         |
# | **Clearing**                             | N/A                 | `clear()`                   | `clear()`                                | `clear()`                                       |
# | **Intersection (if applicable)**         | N/A                 | N/A                         | N/A                                      | Intersection (`intersection()`)                 |
# | **Union (if applicable)**                | N/A                 | N/A                         | N/A                                      | Union (`union()`)                               |
# | **Difference (if applicable)**           | N/A                 | N/A                         | N/A                                      | Difference (`difference()`)                     |
# | **Symmetric Difference (if applicable)** | N/A                 | N/A                         | N/A                                      | Symmetric Difference (`symmetric_difference()`) |

# %% [markdown]
# | Characteristic          | Tuple                   | List                     | Dictionary               | Set                      |
# |-------------------------|-------------------------|--------------------------|--------------------------|--------------------------|
# | **Mutability**          | Immutable               | Mutable                  | Mutable                  | Mutable                  |
# | **Ordered**             | Ordered                 | Ordered                  | Unordered (Python 3.7+)  | Unordered                |
# | **Duplicates Allowed**  | Yes                     | Yes                      | No                       | No (elements are unique) |
# | **Indexing**            | Yes                     | Yes                      | N/A                      | N/A                      |
# | **Syntax**              | `(item1, item2, ...)`  | `[item1, item2, ...]`    | `{'key1': value1, ...}`  | `{item1, item2, ...}`    |
# | **Access by Index**     | Yes                     | Yes                      | N/A                      | N/A                      |
# | **Access by Key**       | N/A                     | N/A                      | Yes                      | N/A                      |
# | **Add Element**         | N/A                     | Append (`append()`)      | Add Key-Value Pair (`dict[key] = value`) | Add Element (`add()`)   |
# | **Remove Element**      | N/A                     | Remove (`remove()`)      | Remove Key-Value Pair (`del dict[key]`) | Remove Element (`remove()`) |
# | **Discard Element**     | N/A                     | N/A                      | N/A                      | Discard Element (`discard()`) |
# | **Check Membership**    | Yes                     | `in` and `not in`        | `in` and `not in`        | `in` and `not in`        |
# | **Length**              | `len()`                 | `len()`                  | `len()`                  | `len()`                  |
# | **Concatenation**       | `+` (concatenation)      | `+` (concatenation)      | N/A                      | Union (`union()`)        |
# | **Slicing**             | Yes                     | Yes                      | N/A                      | N/A                      |
# | **Iteration**           | Yes                     | Yes                      | Keys, Values, Items      | Elements                 |
# | **Sorting**             | N/A                     | `sort()`                 | N/A                      | N/A                      |
# | **Copying**             | Yes (shallow copy)      | `copy()` (shallow copy)  | `copy()` (shallow copy)  | `copy()` (shallow copy) |
# | **Clearing**            | N/A                     | `clear()`                | `clear()`                | `clear()`                |
# | **Intersection**        | N/A                     | N/A                      | N/A                      | Intersection (`intersection()`) |
# | **Union**               | N/A                     | N/A                      | N/A                      | Union (`union()`)        |
# | **Difference**          | N/A                     | N/A                      | N/A                      | Difference (`difference()`) |
# | **Symmetric Difference**| N/A                     | N/A                      | N/A                      | Symmetric Difference (`symmetric_difference()`) |
